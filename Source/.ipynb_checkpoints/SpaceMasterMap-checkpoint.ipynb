# %%
# Import the pandas library
import pandas as pd
# import the library
import folium

# %%
#different map themes at: https://deparkes.co.uk/2016/06/10/folium-map-tiles/

# Make an empty map
m = folium.Map(location=[52.132633,5.291266], tiles="openstreetmap", zoom_start=4)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_236c89825b2f6fcde6c658a4a71ff1e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_236c89825b2f6fcde6c658a4a71ff1e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_236c89825b2f6fcde6c658a4a71ff1e6 = L.map(
#                 &quot;map_236c89825b2f6fcde6c658a4a71ff1e6&quot;,
#                 {
#                     center: [52.132633, 5.291266],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c506e3d353866f181c8edbfdc544b3d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c506e3d353866f181c8edbfdc544b3d5.addTo(map_236c89825b2f6fcde6c658a4a71ff1e6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Make a data frame with dots to show on the map
data = pd.read_csv('WhereAreYou2.csv')

for i, naam in enumerate(data['Name']):
    try:
        float(data['Latitude'][i])
        boolean = True
    except:
        boolean = False

data = data.dropna()
data
# Out:
#        Name           From to (dd/mm/yy)  \
# 0    Julian          07/01/25 - 07/07/25
# 1       Tim          06/01/25 - 31/05/25
# 3     Ersin      28/09/2024 - 30/06/2025
# 5     Marta      14/03/2025 - 17/07/2025
# 6      Mike                      Now-TBD
# 8   Philipp          03/02/25 - 31/07/25
# 10     Emma                   Until june
# 12   Marcus          06/01/25 - 04/04/25
# 13      Leo        from now until future
# 14     Bena         1/4/2025 - 31/8/2025
# 15   Arturs        01/01/2025-04/06/2025
# 17    Emily        01/04/2025-31/08/2025
# 18   Edward  Hopefully May till forever
# 19  Samudra      01/04/2025 - 31/09/2025
# 20     Neel      01/01/2025 - 31/08/2025
#
#                                           Living in  \
# 0                                 Möckmühl, Germany
# 1                                  Cologne, Germany
# 3                                 Helsinki, Finland
# 5                                 Augsburg, Germany
# 6                         Kiruna, Norbotten, Sweden
# 8                                Heilbronn, Germany
# 10                                   Kiruna, Sweden
# 12                                    Sendai, Japan
# 13                                Helsinki, Finland
# 14  Helsinki, Finland but working in Turku, Finland
# 15                                 Helsinki,Finland
# 17                                   Libin, Belgium
# 18                                   Sapporo, Japan
# 19                                Bordeaux, France
# 20                                   Kiruna, Sweden
#
#                          Activity                    Uni/Company  \
# 0                          Thesis             DLR Lampoldshausen
# 1                      Internship                        ESA EAC
# 3                          Thesis               Aalto University
# 5                      Internship                            RFA
# 6           Thesis and Job Hopium                            LTU
# 8                          Thesis                      HyImpulse
# 10                         Thesis                            IRF
# 12                     Internship     Space Robotics Lab, Tohoku
# 13              Internship/thesis    Metsähovi Radio Observatory
# 14  Internship/ thesis/ real work  ASRO (Aboa Space Research Oy)
# 15                         Thesis               Aalto University
# 17                     Internship                       ESA ESEC
# 18                     real work                          Letara
# 19                    Internship        The Exploration Company
# 20                         Thesis                            IRF
#
#                                     Title of Activity   Latitude   Longitude
# 0   Embedded System for Mobile Laser-based Stand-o...  49.322186    9.343709
# 1                         Building VR Moon Simulation  50.867400    7.051200
# 3   Sensor Fusion for Autonomous Navigation of Unm...  60.187297   24.814527
# 5   3D Printing and Additive Manufacturing of RFA'...  48.370500   10.897800
# 6   Design, Assembly, and Validation of the Oxidiz...  67.860000   20.230000
# 8   Development of a Supersonic Split Line nozzle ...  49.233520    9.354352
# 10  Interpreting an unexpected and unexplained sig...  67.856734   20.228932
# 12  Research Internship in Sim-to-Real of Space Ro...  38.268200  140.869400
# 13  Research Assistant, topic: hidden dust in blazars  60.217770   24.393150
# 14  Jr. Systems Engineer, topic: Radiation Dosage ...  60.454510   22.264824
# 15  Concept Research of Piloted Spacecraft Radiati...  60.187297   24.814527
# 17       Design of a shock test facility for CubeSats  49.980946    5.256902
# 18  Design, development and testing of hybrid prop...  43.094270  141.283369
# 19  Propulsion Testing/Test Bench Engineer for Hur...  44.844900    0.656400
# 20  Design of particle analyzer for Venus orbitor ...  67.856734   20.228932

# %%
# add marker one by one on the map
for i in range(0,len(data)):
    folium.Marker(
      location=[data.iloc[i]['Latitude'], data.iloc[i]['Longitude']],
      popup=data.iloc[i]['Name'],
    ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_236c89825b2f6fcde6c658a4a71ff1e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_236c89825b2f6fcde6c658a4a71ff1e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_236c89825b2f6fcde6c658a4a71ff1e6 = L.map(
#                 &quot;map_236c89825b2f6fcde6c658a4a71ff1e6&quot;,
#                 {
#                     center: [52.132633, 5.291266],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c506e3d353866f181c8edbfdc544b3d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c506e3d353866f181c8edbfdc544b3d5.addTo(map_236c89825b2f6fcde6c658a4a71ff1e6);
#
#
#             tile_layer_c506e3d353866f181c8edbfdc544b3d5.addTo(map_236c89825b2f6fcde6c658a4a71ff1e6);
#
#
#             var marker_21093884bcb4102ee56273628cbafd74 = L.marker(
#                 [49.322186, 9.343709],
#                 {
# }
#             ).addTo(map_236c89825b2f6fcde6c658a4a71ff1e6);
#
#
#         var popup_a715fec856e031c3db810ad047b5bb7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de58f5582bf925a14caef7b661125736 = $(`&lt;div id=&quot;html_de58f5582bf925a14caef7b661125736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Julian&lt;/div&gt;`)[0];
#                 popup_a715fec856e031c3db810ad047b5bb7c.setContent(html_de58f5582bf925a14caef7b661125736);
#
#
#
#         marker_21093884bcb4102ee56273628cbafd74.bindPopup(popup_a715fec856e031c3db810ad047b5bb7c)
#         ;
#
#
#
#
#             var marker_dc0440ec35311d053ab5f6e6d2396b25 = L.marker(
#                 [50.8674, 7.0512],
#                 {
# }
#             ).addTo(map_236c89825b2f6fcde6c658a4a71ff1e6);
#
#
#         var popup_d70e2bb8fcec1d8a0f68d4a1cc8d1a89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d41666b5aedcd7071de7f31bbf70a9af = $(`&lt;div id=&quot;html_d41666b5aedcd7071de7f31bbf70a9af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tim&lt;/div&gt;`)[0];
#                 popup_d70e2bb8fcec1d8a0f68d4a1cc8d1a89.setContent(html_d41666b5aedcd7071de7f31bbf70a9af);
#
#
#
#         marker_dc0440ec35311d053ab5f6e6d2396b25.bindPopup(popup_d70e2bb8fcec1d8a0f68d4a1cc8d1a89)
#         ;
#
#
#
#
#             var marker_431f480f6080c422aab21c7656655107 = L.marker(
#                 [60.187297, 24.814527],
#                 {
# }
#             ).addTo(map_236c89825b2f6fcde6c658a4a71ff1e6);
#
#
#         var popup_8dc95f220cdc17e97be8b4dcd52b8015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca54a0818a7ca2c086f1fef2fb0bfa9c = $(`&lt;div id=&quot;html_ca54a0818a7ca2c086f1fef2fb0bfa9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ersin&lt;/div&gt;`)[0];
#                 popup_8dc95f220cdc17e97be8b4dcd52b8015.setContent(html_ca54a0818a7ca2c086f1fef2fb0bfa9c);
#
#
#
#         marker_431f480f6080c422aab21c7656655107.bindPopup(popup_8dc95f220cdc17e97be8b4dcd52b8015)
#         ;
#
#
#
#
#             var marker_d34cc3929a491e35f841df66d53a4b8d = L.marker(
#                 [48.3705, 10.8978],
#                 {
# }
#             ).addTo(map_236c89825b2f6fcde6c658a4a71ff1e6);
#
#
#         var popup_c8150f38fb591b691d72aa803f3488d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3507fb8882fea84f02b3cd734c3d3a8 = $(`&lt;div id=&quot;html_c3507fb8882fea84f02b3cd734c3d3a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marta&lt;/div&gt;`)[0];
#                 popup_c8150f38fb591b691d72aa803f3488d7.setContent(html_c3507fb8882fea84f02b3cd734c3d3a8);
#
#
#
#         marker_d34cc3929a491e35f841df66d53a4b8d.bindPopup(popup_c8150f38fb591b691d72aa803f3488d7)
#         ;
#
#
#
#
#             var marker_df6495649f95515eacc39bfc22b90053 = L.marker(
#                 [67.86, 20.23],
#                 {
# }
#             ).addTo(map_236c89825b2f6fcde6c658a4a71ff1e6);
#
#
#         var popup_582fa987a6ff00dace719ebb36d25fda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebcaec8639fedea66fca09835060bfd6 = $(`&lt;div id=&quot;html_ebcaec8639fedea66fca09835060bfd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mike&lt;/div&gt;`)[0];
#                 popup_582fa987a6ff00dace719ebb36d25fda.setContent(html_ebcaec8639fedea66fca09835060bfd6);
#
#
#
#         marker_df6495649f95515eacc39bfc22b90053.bindPopup(popup_582fa987a6ff00dace719ebb36d25fda)
#         ;
#
#
#
#
#             var marker_a19bf28fdd46368fd46556d04531072e = L.marker(

# %%
m.save('index.html')
