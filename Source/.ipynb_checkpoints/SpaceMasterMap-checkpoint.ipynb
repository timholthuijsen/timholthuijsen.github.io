# %%
# Import the pandas library
import pandas as pd
# import the map library
import folium
#for getting the google sheet
import requests

# %%
#different map themes at: https://deparkes.co.uk/2016/06/10/folium-map-tiles/

# Make an empty map
m = folium.Map(location=[52.132633,5.291266], tiles="openstreetmap", zoom_start=4)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b99e35688db76a865133a782e53c66a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b99e35688db76a865133a782e53c66a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b99e35688db76a865133a782e53c66a6 = L.map(
#                 &quot;map_b99e35688db76a865133a782e53c66a6&quot;,
#                 {
#                     center: [52.132633, 5.291266],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5febebac2f257c3b55e7ca555cbb3811 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5febebac2f257c3b55e7ca555cbb3811.addTo(map_b99e35688db76a865133a782e53c66a6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests

# Publicly shared Google Sheet
sheet_id = "YOUR_SHEET_ID"
gid = "0"   # worksheet/tab ID
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"

# Local save path
save_path = "/path/to/save/my_sheet.csv"

resp = requests.get(url)
resp.raise_for_status()

with open(save_path, "wb") as f:
    f.write(resp.content)

print("Saved:", save_path)

# %%
data = pd.read_csv('WhereAreYou2.csv')
print(data)
# Out:
#         Name           From to (dd/mm/yy)               Living in  \
# 0     Julian    16/09/2025 - prob. 1 year      Stuttgart, Germany
# 1        Tim          17/10/25 - 31/12/25           Sendai, Japan
# 2   Vincent                      01/04/25       Augsburg, Germany
# 3      Ersin                01.07.2025- ?           İzmir, Turkey
# 4       Alex                        06/25       Helsinki, Finland
# 5      Marta      14/03/2025 - 17/07/2025       Augsburg, Germany
# 6       Mike                until forever          Kiruna, Sweden
# 7       Mira                     June - ?         Uppsala, Sweden
# 8    Philipp          03/02/25 - 31/07/25      Heilbronn, Germany
# 9      Louis                        Dunno     Les Mureaux, France
# 10      Emma      Until January at least           Kiruna, Sweden
# 11      Aapo         1/5/2025 - 31/8/2025        Weßling, Germany
# 12    Marcus      16/05/2025 - 18/11/2025    Zurich, Switzerland
# 13       Leo        from now until future       Helsinki, Finland
# 14      Bena                  22/09/05 ->       Helsinki, Finland
# 15    Arturs                 01/01/2025->        Helsinki,Finland
# 16    Markus            Until end of time        Tampere, Finland
# 17     Emily                  01/11/2025-       Augsburg, Germany
# 18    Edward  Hopefully May till forever           Sapporo, Japan
# 19   Samudra               01/04/2025 - ?       Bordeaux, France
# 20      Neel                16/10/2025 ->         Vienna, Austria
# 21    Henkka                01/04/2025 ->       Helsinki, Finland
# 22      Gaia                 15/05/2025->  Delft, The Netherlands
# 23   Claudia              01/05/2015 -> ?          Hekinan, Japan
# 24  Modestas                 Permanently        Stockholm, Sweden
#
#                                 Activity                   Uni/Company  \
# 0                                   Work                 DLR Stuttgart
# 1                             Internship     Space Robotics Laboratory
# 2              Thesis and earning money                          Talos
# 3                                   Work                   TetraCubics
# 4                                    NaN                           NaN
# 5                             Internship                           RFA
# 6   Work, finishing thesis in background                Isar Aerospace
# 7             dilly-dally and job search                           NaN
# 8                                 Thesis                     HyImpulse
# 9                             Internship                   ArianeGroup
# 10                                Thesis                           IRF
# 11                            Internship          DLR Oberpfaffenhofen
# 12                            Internship                          RIVR
# 13                     Internship/thesis   Metsähovi Radio Observatory
# 14                                  Work                          Huld
# 15                                Thesis              Aalto University
# 16                                Thesis                          Saab
# 17                                  Work                           RFA
# 18                            real work                         Letara
# 19                           Internship       The Exploration Company
# 20                                   Job                         TERMA
# 21                        Internship/job                          Huld
# 22                            Thesis/Job  Team Tumbleweed Microgravity
# 23                            Internship                  Pd aerospace
# 24                                   Job                    OHB Sweden
#
#                                     Title of Activity  Latitude [deg]  \
# 0   Engineer at the Institute for Technical Physic...       48.771477
# 1                      Modular autonomous moon robots       50.867400
# 2             Working and Master Thesis in Software.        48.355011
# 3                      Working on Cube Communications       38.327390
# 4                      Getting fines in the metro LOL       60.186110
# 5   3D Printing and Additive Manufacturing of RFA'...       48.370500
# 6                            Propulsion Test Engineer       67.855697
# 7                                                 NaN       59.847744
# 8   Development of a Supersonic Split Line nozzle ...       49.233520
# 9   Navigation software dev for launch vehicle inj...       48.998421
# 10  Interpreting an unexpected and unexplained sig...       67.856734
# 11  Development and Verification of Flight-Softwar...       48.072465
# 12                 Reinforcement learning internship        47.376900
# 13  Research Assistant, topic: hidden dust in blazars       60.217770
# 14                                   Project Manager        60.170830
# 15  Concept Research of Piloted Spacecraft Radiati...       60.187297
# 16                                                NaN       61.502683
# 17                                     Test Engineer        48.366311
# 18  Design, development and testing of hybrid prop...       43.094270
# 19  Propulsion Testing/Test Bench Engineer for Hur...       44.844900
# 20  RF engineer for "some" defence equipment until...       48.208100
# 21  Software validation for the 2nd generation Gal...       60.172778
# 22  Integration of scientific payloads on a satellite       52.011578
# 23  Pulsed detonation engine testing for rocket en...       34.868151
# 24                                     Electrical AIT       59.329300
#
#     Longitude [deg]
# 0          9.150608
# 1          7.051200
# 2         10.879915
# 3         26.307890
# 4         24.827294
# 5         10.897800
# 6         20.228199
# 7         17.651766
# 8          9.354352
# 9          1.924505
# 10        20.228932
# 11        11.252844
# 12         8.541700
# 13        24.393150
# 14        24.937500
# 15        24.814527
# 16        23.764130
# 17        10.928025
# 18       141.283369
# 19        -0.656400
# 20        16.371300
# 21        24.829803
# 22         4.357068
# 23       136.972583
# 24        18.068600

# %%
# Make a data frame with dots to show on the map
data = pd.read_csv('WhereAreYou2.csv')

for i, naam in enumerate(data['Name']):
    try:
        float(data['Latitude'][i])
        boolean = True
    except:
        boolean = False

data = data.dropna()
data
# Out:
#         Name           From to (dd/mm/yy)               Living in  \
# 0     Julian    16/09/2025 - prob. 1 year      Stuttgart, Germany
# 1        Tim          17/10/25 - 31/12/25           Sendai, Japan
# 2   Vincent                      01/04/25       Augsburg, Germany
# 3      Ersin                01.07.2025- ?           İzmir, Turkey
# 5      Marta      14/03/2025 - 17/07/2025       Augsburg, Germany
# 6       Mike                until forever          Kiruna, Sweden
# 8    Philipp          03/02/25 - 31/07/25      Heilbronn, Germany
# 9      Louis                        Dunno     Les Mureaux, France
# 10      Emma      Until January at least           Kiruna, Sweden
# 11      Aapo         1/5/2025 - 31/8/2025        Weßling, Germany
# 12    Marcus      16/05/2025 - 18/11/2025    Zurich, Switzerland
# 13       Leo        from now until future       Helsinki, Finland
# 14      Bena                  22/09/05 ->       Helsinki, Finland
# 15    Arturs                 01/01/2025->        Helsinki,Finland
# 17     Emily                  01/11/2025-       Augsburg, Germany
# 18    Edward  Hopefully May till forever           Sapporo, Japan
# 19   Samudra               01/04/2025 - ?       Bordeaux, France
# 20      Neel                16/10/2025 ->         Vienna, Austria
# 21    Henkka                01/04/2025 ->       Helsinki, Finland
# 22      Gaia                 15/05/2025->  Delft, The Netherlands
# 23   Claudia              01/05/2015 -> ?          Hekinan, Japan
# 24  Modestas                 Permanently        Stockholm, Sweden
#
#                                 Activity                   Uni/Company  \
# 0                                   Work                 DLR Stuttgart
# 1                             Internship     Space Robotics Laboratory
# 2              Thesis and earning money                          Talos
# 3                                   Work                   TetraCubics
# 5                             Internship                           RFA
# 6   Work, finishing thesis in background                Isar Aerospace
# 8                                 Thesis                     HyImpulse
# 9                             Internship                   ArianeGroup
# 10                                Thesis                           IRF
# 11                            Internship          DLR Oberpfaffenhofen
# 12                            Internship                          RIVR
# 13                     Internship/thesis   Metsähovi Radio Observatory
# 14                                  Work                          Huld
# 15                                Thesis              Aalto University
# 17                                  Work                           RFA
# 18                            real work                         Letara
# 19                           Internship       The Exploration Company
# 20                                   Job                         TERMA
# 21                        Internship/job                          Huld
# 22                            Thesis/Job  Team Tumbleweed Microgravity
# 23                            Internship                  Pd aerospace
# 24                                   Job                    OHB Sweden
#
#                                     Title of Activity  Latitude [deg]  \
# 0   Engineer at the Institute for Technical Physic...       48.771477
# 1                      Modular autonomous moon robots       50.867400
# 2             Working and Master Thesis in Software.        48.355011
# 3                      Working on Cube Communications       38.327390
# 5   3D Printing and Additive Manufacturing of RFA'...       48.370500
# 6                            Propulsion Test Engineer       67.855697
# 8   Development of a Supersonic Split Line nozzle ...       49.233520
# 9   Navigation software dev for launch vehicle inj...       48.998421
# 10  Interpreting an unexpected and unexplained sig...       67.856734
# 11  Development and Verification of Flight-Softwar...       48.072465
# 12                 Reinforcement learning internship        47.376900
# 13  Research Assistant, topic: hidden dust in blazars       60.217770
# 14                                   Project Manager        60.170830
# 15  Concept Research of Piloted Spacecraft Radiati...       60.187297
# 17                                     Test Engineer        48.366311
# 18  Design, development and testing of hybrid prop...       43.094270
# 19  Propulsion Testing/Test Bench Engineer for Hur...       44.844900
# 20  RF engineer for "some" defence equipment until...       48.208100
# 21  Software validation for the 2nd generation Gal...       60.172778
# 22  Integration of scientific payloads on a satellite       52.011578
# 23  Pulsed detonation engine testing for rocket en...       34.868151
# 24                                     Electrical AIT       59.329300
#
#     Longitude [deg]
# 0          9.150608
# 1          7.051200
# 2         10.879915
# 3         26.307890
# 5         10.897800
# 6         20.228199
# 8          9.354352
# 9          1.924505
# 10        20.228932
# 11        11.252844
# 12         8.541700
# 13        24.393150
# 14        24.937500
# 15        24.814527
# 17        10.928025
# 18       141.283369
# 19        -0.656400
# 20        16.371300
# 21        24.829803
# 22         4.357068
# 23       136.972583
# 24        18.068600

# %%
# add marker one by one on the map
for i in range(0,len(data)):
    folium.Marker(
      location=[data.iloc[i]['Latitude [deg]'], data.iloc[i]['Longitude [deg]']],
      popup=data.iloc[i]['Name'],
    ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b99e35688db76a865133a782e53c66a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b99e35688db76a865133a782e53c66a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b99e35688db76a865133a782e53c66a6 = L.map(
#                 &quot;map_b99e35688db76a865133a782e53c66a6&quot;,
#                 {
#                     center: [52.132633, 5.291266],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5febebac2f257c3b55e7ca555cbb3811 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5febebac2f257c3b55e7ca555cbb3811.addTo(map_b99e35688db76a865133a782e53c66a6);
#
#
#             tile_layer_5febebac2f257c3b55e7ca555cbb3811.addTo(map_b99e35688db76a865133a782e53c66a6);
#
#
#             var marker_72886ad329f7255d73772ff0f0856388 = L.marker(
#                 [48.771477, 9.150608],
#                 {
# }
#             ).addTo(map_b99e35688db76a865133a782e53c66a6);
#
#
#         var popup_687ae913ddcbfb214e9f0908410c63d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d915a5b354950eaf8e21292c246e044 = $(`&lt;div id=&quot;html_0d915a5b354950eaf8e21292c246e044&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Julian&lt;/div&gt;`)[0];
#                 popup_687ae913ddcbfb214e9f0908410c63d5.setContent(html_0d915a5b354950eaf8e21292c246e044);
#
#
#
#         marker_72886ad329f7255d73772ff0f0856388.bindPopup(popup_687ae913ddcbfb214e9f0908410c63d5)
#         ;
#
#
#
#
#             var marker_0eb6ef654252866587ca1f7569688d71 = L.marker(
#                 [50.8674, 7.0512],
#                 {
# }
#             ).addTo(map_b99e35688db76a865133a782e53c66a6);
#
#
#         var popup_73f006224ee7b9ad76229f4960782b5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_367a557ab6462d70f0b84033fa16d3ef = $(`&lt;div id=&quot;html_367a557ab6462d70f0b84033fa16d3ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tim&lt;/div&gt;`)[0];
#                 popup_73f006224ee7b9ad76229f4960782b5c.setContent(html_367a557ab6462d70f0b84033fa16d3ef);
#
#
#
#         marker_0eb6ef654252866587ca1f7569688d71.bindPopup(popup_73f006224ee7b9ad76229f4960782b5c)
#         ;
#
#
#
#
#             var marker_8ed93475e661efbfca08f931d5ab2753 = L.marker(
#                 [48.355011, 10.8799155],
#                 {
# }
#             ).addTo(map_b99e35688db76a865133a782e53c66a6);
#
#
#         var popup_c6bd17e1c146cd7853fb5d88819232fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c939e5787ced53c292dc24ba637a4f9 = $(`&lt;div id=&quot;html_0c939e5787ced53c292dc24ba637a4f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vincent &lt;/div&gt;`)[0];
#                 popup_c6bd17e1c146cd7853fb5d88819232fc.setContent(html_0c939e5787ced53c292dc24ba637a4f9);
#
#
#
#         marker_8ed93475e661efbfca08f931d5ab2753.bindPopup(popup_c6bd17e1c146cd7853fb5d88819232fc)
#         ;
#
#
#
#
#             var marker_1f7bb5515bc3041e975b940931078eb6 = L.marker(
#                 [38.32739, 26.30789],
#                 {
# }
#             ).addTo(map_b99e35688db76a865133a782e53c66a6);
#
#
#         var popup_2bb5dae917542a63d4a2ed883838b90a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fb6cef4964c95c9b5f9f94a4fffb1a5 = $(`&lt;div id=&quot;html_3fb6cef4964c95c9b5f9f94a4fffb1a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ersin&lt;/div&gt;`)[0];
#                 popup_2bb5dae917542a63d4a2ed883838b90a.setContent(html_3fb6cef4964c95c9b5f9f94a4fffb1a5);
#
#
#
#         marker_1f7bb5515bc3041e975b940931078eb6.bindPopup(popup_2bb5dae917542a63d4a2ed883838b90a)
#         ;
#
#
#
#
#             var marker_450974b0bb84f1f5f3a6d527eb36f8bf = L.marker(
#                 [48.3705, 10.8978],
#                 {
# }
#             ).addTo(map_b99e35688db76a865133a782e53c66a6);
#
#
#         var popup_b3a62c8a1b68555b5bc5365cc6097ca2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d25c0701602f2e127c0af739800e4782 = $(`&lt;div id=&quot;html_d25c0701602f2e127c0af739800e4782&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marta&lt;/div&gt;`)[0];
#                 popup_b3a62c8a1b68555b5bc5365cc6097ca2.setContent(html_d25c070160

# %%
m.save('index.html')
