# %%
# Import the pandas library
import pandas as pd
# import the library
import folium

# %%
# Make an empty map
m = folium.Map(location=[52.132633,5.291266], tiles="OpenStreetMap", zoom_start=4)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6cd89cc12dddd2999408041e386807dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6cd89cc12dddd2999408041e386807dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6cd89cc12dddd2999408041e386807dd = L.map(
#                 &quot;map_6cd89cc12dddd2999408041e386807dd&quot;,
#                 {
#                     center: [52.132633, 5.291266],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ad6711d06a7fcf7b330b5d285b05122 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ad6711d06a7fcf7b330b5d285b05122.addTo(map_6cd89cc12dddd2999408041e386807dd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Make a data frame with dots to show on the map
data = pd.read_csv('map.csv')

for i, naam in enumerate(data['Naam']):
    try:
        float(data['Latitude'][i])
        boolean = True
    except:
        boolean = False
    if not boolean:
        data['Latitude'][i] = 0
        data['Longitude'][i] = 0
#data['Latitude'][22], data['Longitude'][22]= 51.615420, 4.778410
data
# Out:
#                      Tijdstempel                  Naam   Latitude  Longitude
# 0    2022/03/07 1:00:23 p.m. EET       Tim Holthuijsen  52.367824   4.897648
# 1    2022/03/07 1:09:18 p.m. EET     Ariel Ebersberger  48.208200  16.373800
# 2    2022/03/07 1:09:18 p.m. EET        Sudarshan Bhat  51.076482  13.728795
# 3    2022/03/07 5:52:00 p.m. EET      Timon Schnauffer  48.202717  16.337829
# 4    2022/03/07 8:28:00 p.m. EET        Dimitri Buryak  48.182707  16.415447
# 5    2022/03/07 8:29:00 p.m. EET     Mikhail Maximchuk  52.092876   5.104480
# 6    2022/03/07 8:29:00 p.m. EET      Markus Renoldner  59.329300  18.068600
# 7    2022/03/07 8:29:00 p.m. EET       Cristian Ferent  52.070500   4.300700
# 8    2022/03/07 8:28:00 p.m. EET        Marco Zambolin  51.987322   4.346493
# 9    2022/03/08 1:24:00 p.m. IST   Anjaney Shrivastava  26.205913  78.210033
# 10   2022/03/07 8:28:00 p.m. EET          Luna Warzawa  52.361797   4.954757
# 11   2022/03/07 8:28:00 p.m. EET        One Mikulskyte  52.354702   4.954757
# 12   2022/03/07 9:23:00 p.m. EET        Lorenz Veithen  52.014280   4.331540
# 13   2022/03/08 9:03:00 a.m. EET          Amelie Finan  48.233300  16.316700
# 14   2022/03/08 9:23:00 a.m. EET        Sam de Wringer  52.354060   4.884235
# 15  2022/03/08 10:20:00 a.m. EET           Garnet John  47.431482  19.095643
# 16      2022/03/08 12:06 p.m EET       Kristián Cuervo  52.002655   4.375425
# 17      2022/03/08 12:06 p.m EET  Julian Rothenbuchner  52.010258   4.350815
# 18     2022/03/08 13:31 p.m. EET      James Kingsnorth  52.526435   4.961387
# 19     2022/03/09 20:31 p.m. EET    Michael Sandrieser  46.726614  14.091202
# 20    2022/03/09 22:318 p.m. EET     Yara Eggenfellner  48.210922  16.314244
# 21       2022/03/19 15:50 pm EET        Anisha Nookala  48.205603  16.365772

# %%
# add marker one by one on the map
for i in range(0,len(data)):
    folium.Marker(
      location=[data.iloc[i]['Latitude'], data.iloc[i]['Longitude']],
      popup=data.iloc[i]['Naam'],
    ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6cd89cc12dddd2999408041e386807dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6cd89cc12dddd2999408041e386807dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6cd89cc12dddd2999408041e386807dd = L.map(
#                 &quot;map_6cd89cc12dddd2999408041e386807dd&quot;,
#                 {
#                     center: [52.132633, 5.291266],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ad6711d06a7fcf7b330b5d285b05122 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ad6711d06a7fcf7b330b5d285b05122.addTo(map_6cd89cc12dddd2999408041e386807dd);
#
#
#             tile_layer_0ad6711d06a7fcf7b330b5d285b05122.addTo(map_6cd89cc12dddd2999408041e386807dd);
#
#
#             var marker_ddc41a78c66abc7dc9fb45588fc591ff = L.marker(
#                 [52.367824, 4.897648],
#                 {
# }
#             ).addTo(map_6cd89cc12dddd2999408041e386807dd);
#
#
#         var popup_2e75fd70c85a27b34049e4d69954a477 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_253b4e5b06490571c629542270a58988 = $(`&lt;div id=&quot;html_253b4e5b06490571c629542270a58988&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tim Holthuijsen&lt;/div&gt;`)[0];
#                 popup_2e75fd70c85a27b34049e4d69954a477.setContent(html_253b4e5b06490571c629542270a58988);
#
#
#
#         marker_ddc41a78c66abc7dc9fb45588fc591ff.bindPopup(popup_2e75fd70c85a27b34049e4d69954a477)
#         ;
#
#
#
#
#             var marker_1cb4c10b6fac1d6adf29f413898ec557 = L.marker(
#                 [48.2082, 16.3738],
#                 {
# }
#             ).addTo(map_6cd89cc12dddd2999408041e386807dd);
#
#
#         var popup_4b651c7a85b8bd4f3099452e345d76c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c02923a6d07529d978496373a49d5bb8 = $(`&lt;div id=&quot;html_c02923a6d07529d978496373a49d5bb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ariel Ebersberger&lt;/div&gt;`)[0];
#                 popup_4b651c7a85b8bd4f3099452e345d76c9.setContent(html_c02923a6d07529d978496373a49d5bb8);
#
#
#
#         marker_1cb4c10b6fac1d6adf29f413898ec557.bindPopup(popup_4b651c7a85b8bd4f3099452e345d76c9)
#         ;
#
#
#
#
#             var marker_5f8a4332071652bc833a979829e6cd59 = L.marker(
#                 [51.07648173, 13.72879491],
#                 {
# }
#             ).addTo(map_6cd89cc12dddd2999408041e386807dd);
#
#
#         var popup_5407dcc4e3f93079eb22bddb818fe42b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7183bd11dd55f7b49cfa2f6005a1c123 = $(`&lt;div id=&quot;html_7183bd11dd55f7b49cfa2f6005a1c123&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sudarshan Bhat&lt;/div&gt;`)[0];
#                 popup_5407dcc4e3f93079eb22bddb818fe42b.setContent(html_7183bd11dd55f7b49cfa2f6005a1c123);
#
#
#
#         marker_5f8a4332071652bc833a979829e6cd59.bindPopup(popup_5407dcc4e3f93079eb22bddb818fe42b)
#         ;
#
#
#
#
#             var marker_c28552276340ac9282d8b3c7c0338505 = L.marker(
#                 [48.20271698, 16.33782925],
#                 {
# }
#             ).addTo(map_6cd89cc12dddd2999408041e386807dd);
#
#
#         var popup_dc17a84bb80f6237cb9a17805cde6eb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_221a754426f8e769a646fee2fab0089c = $(`&lt;div id=&quot;html_221a754426f8e769a646fee2fab0089c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timon Schnauffer&lt;/div&gt;`)[0];
#                 popup_dc17a84bb80f6237cb9a17805cde6eb1.setContent(html_221a754426f8e769a646fee2fab0089c);
#
#
#
#         marker_c28552276340ac9282d8b3c7c0338505.bindPopup(popup_dc17a84bb80f6237cb9a17805cde6eb1)
#         ;
#
#
#
#
#             var marker_0981edb9ee3498926cb6d6e9d0448c4d = L.marker(
#                 [48.18270721, 16.41544734],
#                 {
# }
#             ).addTo(map_6cd89cc12dddd2999408041e386807dd);
#
#
#         var popup_67aee6254fe30910d182405884f44f6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28a5136e5b87bf0c46d741a3eed9c246 = $(`&lt;div id=&quot;html_28a5136e5b87bf0c46d741a3eed9c246&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dimitri Buryak&lt;/div&gt;`)[0];
#                 popup_67aee6254fe30910d182405884f44f6b.setContent(html_28a5136e5b87bf0c46d741a3eed9c246);
#
#
#
#         marker_0981edb9ee3498926cb6d6e9d0448c4d.bindPopup(popup_67aee6254fe30910d182405884f44f6b)
#         ;

# %%
m.save('index.html')
