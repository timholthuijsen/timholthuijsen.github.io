# %%
# Import the pandas library
import pandas as pd
# import the map library
import folium
#for getting the google sheet
import requests

# %%
#different map themes at: https://deparkes.co.uk/2016/06/10/folium-map-tiles/

# Make an empty map
m = folium.Map(location=[52.132633,5.291266], tiles="openstreetmap", zoom_start=4)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea0775b20a421046e26d958402fa7d67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea0775b20a421046e26d958402fa7d67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea0775b20a421046e26d958402fa7d67 = L.map(
#                 &quot;map_ea0775b20a421046e26d958402fa7d67&quot;,
#                 {
#                     center: [52.132633, 5.291266],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fcd18e562fcaadc81202eadb78b4298 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fcd18e562fcaadc81202eadb78b4298.addTo(map_ea0775b20a421046e26d958402fa7d67);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests
import os

sheet_id = "1bV4WUZNM4LBBeQutiQXLa_JhxoFIE7rHnGCG4Ili7LY"
gid = "0"

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"

save_path = "WhereAreYou.csv"

resp = requests.get(url)
resp.raise_for_status()

with open(save_path, "wb") as f:
    f.write(resp.content)

print("Saved:", save_path)
# Out:
# Saved: WhereAreYou.csv

# %%
data = pd.read_csv('WhereAreYou.csv')
print(data)
# Out:
#         Name           From to (dd/mm/yy)               Living in  \
# 0     Julian    16/09/2025 - prob. 1 year      Stuttgart, Germany
# 1        Tim          17/10/25 - 31/12/25           Sendai, Japan
# 2   Vincent                      01/04/25       Augsburg, Germany
# 3      Ersin                01.07.2025- ?           İzmir, Turkey
# 4       Alex                        06/25       Helsinki, Finland
# 5      Marta      14/03/2025 - 17/07/2025       Augsburg, Germany
# 6       Mike                until forever          Kiruna, Sweden
# 7       Mira                     June - ?         Uppsala, Sweden
# 8    Philipp          03/02/25 - 31/07/25      Heilbronn, Germany
# 9      Louis                        Dunno     Les Mureaux, France
# 10      Emma      Until January at least           Kiruna, Sweden
# 11      Aapo         1/5/2025 - 31/8/2025        Weßling, Germany
# 12    Marcus      16/05/2025 - 18/11/2025    Zurich, Switzerland
# 13       Leo        from now until future       Helsinki, Finland
# 14      Bena                  22/09/05 ->       Helsinki, Finland
# 15    Arturs                 01/01/2025->        Helsinki,Finland
# 16    Markus            Until end of time        Tampere, Finland
# 17     Emily                  01/11/2025-       Augsburg, Germany
# 18    Edward  Hopefully May till forever           Sapporo, Japan
# 19   Samudra               01/04/2025 - ?       Bordeaux, France
# 20      Neel                16/10/2025 ->         Vienna, Austria
# 21    Henkka                01/04/2025 ->       Helsinki, Finland
# 22      Gaia                 15/05/2025->  Delft, The Netherlands
# 23   Claudia              01/05/2015 -> ?          Hekinan, Japan
# 24  Modestas                 Permanently        Stockholm, Sweden
#
#                                 Activity                   Uni/Company  \
# 0                                   Work                 DLR Stuttgart
# 1                             Internship     Space Robotics Laboratory
# 2              Thesis and earning money                          Talos
# 3                                   Work                   TetraCubics
# 4                                    NaN                           NaN
# 5                             Internship                           RFA
# 6   Work, finishing thesis in background                Isar Aerospace
# 7             dilly-dally and job search                           NaN
# 8                                 Thesis                     HyImpulse
# 9                             Internship                   ArianeGroup
# 10                                Thesis                           IRF
# 11                            Internship          DLR Oberpfaffenhofen
# 12                            Internship                          RIVR
# 13                     Internship/thesis   Metsähovi Radio Observatory
# 14                                  Work                          Huld
# 15                                Thesis              Aalto University
# 16                                Thesis                          Saab
# 17                                  Work                           RFA
# 18                            real work                         Letara
# 19                           Internship       The Exploration Company
# 20                                   Job                         TERMA
# 21                        Internship/job                          Huld
# 22                            Thesis/Job  Team Tumbleweed Microgravity
# 23                            Internship                  Pd aerospace
# 24                                   Job                    OHB Sweden
#
#                                     Title of Activity  Latitude [deg]  \
# 0   Engineer at the Institute for Technical Physic...       48.771477
# 1                      Modular autonomous moon robots       38.268200
# 2             Working and Master Thesis in Software.        48.355011
# 3                      Working on Cube Communications       38.327390
# 4                      Getting fines in the metro LOL       60.186110
# 5   3D Printing and Additive Manufacturing of RFA'...       48.370500
# 6                            Propulsion Test Engineer       67.855697
# 7                                                 NaN       59.847744
# 8   Development of a Supersonic Split Line nozzle ...       49.233520
# 9   Navigation software dev for launch vehicle inj...       48.998421
# 10  Interpreting an unexpected and unexplained sig...       67.856734
# 11  Development and Verification of Flight-Softwar...       48.072465
# 12                 Reinforcement learning internship        47.376900
# 13  Research Assistant, topic: hidden dust in blazars       60.217770
# 14                                   Project Manager        60.170830
# 15  Concept Research of Piloted Spacecraft Radiati...       60.187297
# 16                                                NaN       61.502683
# 17                                     Test Engineer        48.366311
# 18  Design, development and testing of hybrid prop...       43.094270
# 19  Propulsion Testing/Test Bench Engineer for Hur...       44.844900
# 20  RF engineer for "some" defence equipment until...       48.208100
# 21  Software validation for the 2nd generation Gal...       60.172778
# 22  Integration of scientific payloads on a satellite       52.011578
# 23  Pulsed detonation engine testing for rocket en...       34.868151
# 24                                     Electrical AIT       59.329300
#
#     Longitude [deg]
# 0          9.150608
# 1        140.869400
# 2         10.879915
# 3         26.307890
# 4         24.827294
# 5         10.897800
# 6         20.228199
# 7         17.651766
# 8          9.354352
# 9          1.924505
# 10        20.228932
# 11        11.252844
# 12         8.541700
# 13        24.393150
# 14        24.937500
# 15        24.814527
# 16        23.764130
# 17        10.928025
# 18       141.283369
# 19        -0.656400
# 20        16.371300
# 21        24.829803
# 22         4.357068
# 23       136.972583
# 24        18.068600

# %%
# Make a data frame with dots to show on the map
data = pd.read_csv('WhereAreYou.csv')

for i, naam in enumerate(data['Name']):
    try:
        float(data['Latitude'][i])
        boolean = True
    except:
        boolean = False

data = data.dropna()
data
# Out:
#         Name           From to (dd/mm/yy)               Living in  \
# 0     Julian    16/09/2025 - prob. 1 year      Stuttgart, Germany
# 1        Tim          17/10/25 - 31/12/25           Sendai, Japan
# 2   Vincent                      01/04/25       Augsburg, Germany
# 3      Ersin                01.07.2025- ?           İzmir, Turkey
# 5      Marta      14/03/2025 - 17/07/2025       Augsburg, Germany
# 6       Mike                until forever          Kiruna, Sweden
# 8    Philipp          03/02/25 - 31/07/25      Heilbronn, Germany
# 9      Louis                        Dunno     Les Mureaux, France
# 10      Emma      Until January at least           Kiruna, Sweden
# 11      Aapo         1/5/2025 - 31/8/2025        Weßling, Germany
# 12    Marcus      16/05/2025 - 18/11/2025    Zurich, Switzerland
# 13       Leo        from now until future       Helsinki, Finland
# 14      Bena                  22/09/05 ->       Helsinki, Finland
# 15    Arturs                 01/01/2025->        Helsinki,Finland
# 17     Emily                  01/11/2025-       Augsburg, Germany
# 18    Edward  Hopefully May till forever           Sapporo, Japan
# 19   Samudra               01/04/2025 - ?       Bordeaux, France
# 20      Neel                16/10/2025 ->         Vienna, Austria
# 21    Henkka                01/04/2025 ->       Helsinki, Finland
# 22      Gaia                 15/05/2025->  Delft, The Netherlands
# 23   Claudia              01/05/2015 -> ?          Hekinan, Japan
# 24  Modestas                 Permanently        Stockholm, Sweden
#
#                                 Activity                   Uni/Company  \
# 0                                   Work                 DLR Stuttgart
# 1                             Internship     Space Robotics Laboratory
# 2              Thesis and earning money                          Talos
# 3                                   Work                   TetraCubics
# 5                             Internship                           RFA
# 6   Work, finishing thesis in background                Isar Aerospace
# 8                                 Thesis                     HyImpulse
# 9                             Internship                   ArianeGroup
# 10                                Thesis                           IRF
# 11                            Internship          DLR Oberpfaffenhofen
# 12                            Internship                          RIVR
# 13                     Internship/thesis   Metsähovi Radio Observatory
# 14                                  Work                          Huld
# 15                                Thesis              Aalto University
# 17                                  Work                           RFA
# 18                            real work                         Letara
# 19                           Internship       The Exploration Company
# 20                                   Job                         TERMA
# 21                        Internship/job                          Huld
# 22                            Thesis/Job  Team Tumbleweed Microgravity
# 23                            Internship                  Pd aerospace
# 24                                   Job                    OHB Sweden
#
#                                     Title of Activity  Latitude [deg]  \
# 0   Engineer at the Institute for Technical Physic...       48.771477
# 1                      Modular autonomous moon robots       38.268200
# 2             Working and Master Thesis in Software.        48.355011
# 3                      Working on Cube Communications       38.327390
# 5   3D Printing and Additive Manufacturing of RFA'...       48.370500
# 6                            Propulsion Test Engineer       67.855697
# 8   Development of a Supersonic Split Line nozzle ...       49.233520
# 9   Navigation software dev for launch vehicle inj...       48.998421
# 10  Interpreting an unexpected and unexplained sig...       67.856734
# 11  Development and Verification of Flight-Softwar...       48.072465
# 12                 Reinforcement learning internship        47.376900
# 13  Research Assistant, topic: hidden dust in blazars       60.217770
# 14                                   Project Manager        60.170830
# 15  Concept Research of Piloted Spacecraft Radiati...       60.187297
# 17                                     Test Engineer        48.366311
# 18  Design, development and testing of hybrid prop...       43.094270
# 19  Propulsion Testing/Test Bench Engineer for Hur...       44.844900
# 20  RF engineer for "some" defence equipment until...       48.208100
# 21  Software validation for the 2nd generation Gal...       60.172778
# 22  Integration of scientific payloads on a satellite       52.011578
# 23  Pulsed detonation engine testing for rocket en...       34.868151
# 24                                     Electrical AIT       59.329300
#
#     Longitude [deg]
# 0          9.150608
# 1        140.869400
# 2         10.879915
# 3         26.307890
# 5         10.897800
# 6         20.228199
# 8          9.354352
# 9          1.924505
# 10        20.228932
# 11        11.252844
# 12         8.541700
# 13        24.393150
# 14        24.937500
# 15        24.814527
# 17        10.928025
# 18       141.283369
# 19        -0.656400
# 20        16.371300
# 21        24.829803
# 22         4.357068
# 23       136.972583
# 24        18.068600

# %%
# add marker one by one on the map
for i in range(0,len(data)):
    folium.Marker(
      location=[data.iloc[i]['Latitude [deg]'], data.iloc[i]['Longitude [deg]']],
      popup=data.iloc[i]['Name'],
    ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea0775b20a421046e26d958402fa7d67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea0775b20a421046e26d958402fa7d67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea0775b20a421046e26d958402fa7d67 = L.map(
#                 &quot;map_ea0775b20a421046e26d958402fa7d67&quot;,
#                 {
#                     center: [52.132633, 5.291266],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9fcd18e562fcaadc81202eadb78b4298 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9fcd18e562fcaadc81202eadb78b4298.addTo(map_ea0775b20a421046e26d958402fa7d67);
#
#
#             tile_layer_9fcd18e562fcaadc81202eadb78b4298.addTo(map_ea0775b20a421046e26d958402fa7d67);
#
#
#             var marker_ecf936be06ae27a094237e1b9770aa33 = L.marker(
#                 [48.771477, 9.150608],
#                 {
# }
#             ).addTo(map_ea0775b20a421046e26d958402fa7d67);
#
#
#         var popup_d29eacc9ca9d4876f15bf6abd1a7157b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bfd12677d8c9b7bcdfd1d8397ce8d96 = $(`&lt;div id=&quot;html_9bfd12677d8c9b7bcdfd1d8397ce8d96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Julian&lt;/div&gt;`)[0];
#                 popup_d29eacc9ca9d4876f15bf6abd1a7157b.setContent(html_9bfd12677d8c9b7bcdfd1d8397ce8d96);
#
#
#
#         marker_ecf936be06ae27a094237e1b9770aa33.bindPopup(popup_d29eacc9ca9d4876f15bf6abd1a7157b)
#         ;
#
#
#
#
#             var marker_5f7253e4bd8bda9bdc9044837a4b250c = L.marker(
#                 [38.2682, 140.8694],
#                 {
# }
#             ).addTo(map_ea0775b20a421046e26d958402fa7d67);
#
#
#         var popup_4b33517a128045bfb19cb6bd1b2fd75e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ad73cc7db3e3bcb8a793114101ce4d1 = $(`&lt;div id=&quot;html_1ad73cc7db3e3bcb8a793114101ce4d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tim&lt;/div&gt;`)[0];
#                 popup_4b33517a128045bfb19cb6bd1b2fd75e.setContent(html_1ad73cc7db3e3bcb8a793114101ce4d1);
#
#
#
#         marker_5f7253e4bd8bda9bdc9044837a4b250c.bindPopup(popup_4b33517a128045bfb19cb6bd1b2fd75e)
#         ;
#
#
#
#
#             var marker_04ff55e6deb6d6123e9d21c325404c8a = L.marker(
#                 [48.355011, 10.8799155],
#                 {
# }
#             ).addTo(map_ea0775b20a421046e26d958402fa7d67);
#
#
#         var popup_a12b541ac570f1e656db0f86907ad477 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f787af098398c8471533d862134e8b7c = $(`&lt;div id=&quot;html_f787af098398c8471533d862134e8b7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Vincent &lt;/div&gt;`)[0];
#                 popup_a12b541ac570f1e656db0f86907ad477.setContent(html_f787af098398c8471533d862134e8b7c);
#
#
#
#         marker_04ff55e6deb6d6123e9d21c325404c8a.bindPopup(popup_a12b541ac570f1e656db0f86907ad477)
#         ;
#
#
#
#
#             var marker_53d9e8feb1dc1cd96e90b46cde1d43b7 = L.marker(
#                 [38.32739, 26.30789],
#                 {
# }
#             ).addTo(map_ea0775b20a421046e26d958402fa7d67);
#
#
#         var popup_b7e7ad05858586202120646542ddcf45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49a682afd11cd978bb4b1ccb707cd1ac = $(`&lt;div id=&quot;html_49a682afd11cd978bb4b1ccb707cd1ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ersin&lt;/div&gt;`)[0];
#                 popup_b7e7ad05858586202120646542ddcf45.setContent(html_49a682afd11cd978bb4b1ccb707cd1ac);
#
#
#
#         marker_53d9e8feb1dc1cd96e90b46cde1d43b7.bindPopup(popup_b7e7ad05858586202120646542ddcf45)
#         ;
#
#
#
#
#             var marker_818325c2c2ffd9ca954d1fc02f7c7a81 = L.marker(
#                 [48.3705, 10.8978],
#                 {
# }
#             ).addTo(map_ea0775b20a421046e26d958402fa7d67);
#
#
#         var popup_fc00e623492f85b74a47e6dc6faa2e91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_266e7abb3ac50a0a5e499d270261ffbd = $(`&lt;div id=&quot;html_266e7abb3ac50a0a5e499d270261ffbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marta&lt;/div&gt;`)[0];
#                 popup_fc00e623492f85b74a47e6dc6faa2e91.setContent(html_266e7abb

# %%
m.save('index.html')
